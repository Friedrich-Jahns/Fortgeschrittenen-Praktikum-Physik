# %%
__file__ = 'erosion_and_dilation.ipynb'
import sys
import pathlib
sys.path.append(str(pathlib.Path(__file__).absolute().parent.parent)+"/FP7_lib")
#hallo
import functions as f
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import io

# %%
data = []
for file in sorted(os.listdir('Data')):
    
        with open('Data/'+file, mode='rb') as tf:
            print(file)
            datain = np.genfromtxt(tf,delimiter="\t",skip_header=15).T
            data.append([file.split('.')[0],datain[0],datain[1],np.sqrt(datain[1].clip(min=1))])
print(data)
# Out:
# Papier_dick.csv
# Papier_dünn.csv
# alu.csv
# [['Papier_dick', array([0.000e+00, 1.000e+00, 2.000e+00, ..., 2.045e+03, 2.046e+03,
#        2.047e+03]), array([9., 3., 5., ..., 0., 0., 0.]), array([3.        , 1.73205081, 2.23606798, ..., 1.        , 1.        ,
#        1.        ])], ['Papier_dünn', array([0.000e+00, 1.000e+00, 2.000e+00, ..., 2.045e+03, 2.046e+03,
#        2.047e+03]), array([87., 75., 80., ...,  0.,  0.,  0.]), array([9.32737905, 8.66025404, 8.94427191, ..., 1.        , 1.        ,
#        1.        ])], ['alu', array([0.000e+00, 1.000e+00, 2.000e+00, ..., 2.045e+03, 2.046e+03,
#        2.047e+03]), array([26., 32., 29., ...,  0.,  0.,  0.]), array([5.09901951, 5.65685425, 5.38516481, ..., 1.        , 1.        ,
#        1.        ])]]

# %%
for i in data:

    if i[0] == 'alu':

        print("#########################################################"+str(i[0]))

        res = f.gaus1fit(i,0,500,1100,900,1200)
        plt.savefig("Results/alu.pdf")
        plt.show()

    if i[0] == 'Papier_dick':

        print("#########################################################"+str(i[0]))

        res = f.gaus1fit(i,0,500,1100,900,1200)
        plt.savefig("Results/Papier_dick.pdf")
        plt.show()

    if i[0] == 'Papier_dünn':

        print("#########################################################"+str(i[0]))

        res = f.gaus1fit(i,100,500,300,200,400)
        plt.savefig("Results/Papier_dünn.pdf")
        plt.show()
# Out:
# #########################################################Papier_dick
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 50
#     # data points      = 500
#     # variables        = 3
#     chi-square         = 249.695893
#     reduced chi-square = 0.50240622
#     Akaike info crit   = -341.182176
#     Bayesian info crit = -328.538351
#     R-squared          = 0.90094577
# [[Variables]]
#     amplitude:  8249.01122 +/- 10991.0114 (133.24%) (init = 1458)
#     center:    -320.445277 +/- 232.150073 (72.45%) (init = 33.30769)
#     sigma:      214.918320 +/- 57.5448942 (26.78%) (init = 40.5)
#     fwhm:       506.093957 +/- 135.507867 (26.78%) == '2.3548200*sigma'
#     height:     15.3122336 +/- 16.3612298 (106.85%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, center) = -0.998
#     C(center, sigma)     = -0.995
#     C(amplitude, sigma)  = 0.988
# #########################################################Papier_dünn
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 400
#     # variables        = 3
#     chi-square         = 483.128205
#     reduced chi-square = 1.21694762
#     Akaike info crit   = 81.5270027
#     Bayesian info crit = 93.5013964
#     R-squared          = 0.99595543
# [[Variables]]
#     amplitude:  26467.5221 +/- 356.109766 (1.35%) (init = 36531)
#     center:     242.462934 +/- 2.36537566 (0.98%) (init = 246.2085)
#     sigma:      152.604525 +/- 2.55309596 (1.67%) (init = 148.5)
#     fwhm:       359.356187 +/- 6.01208144 (1.67%) == '2.3548200*sigma'
#     height:     69.1920121 +/- 0.69196049 (1.00%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, sigma)  = 0.802
#     C(amplitude, center) = -0.665
#     C(center, sigma)     = -0.665
# #########################################################alu
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 500
#     # variables        = 3
#     chi-square         = 2061.35070
#     reduced chi-square = 4.14758692
#     Akaike info crit   = 714.254314
#     Bayesian info crit = 726.898138
#     R-squared          = 0.99913297
# [[Variables]]
#     amplitude:  23882.8366 +/- 314.780534 (1.32%) (init = 34263)
#     center:     309.169766 +/- 0.60522223 (0.20%) (init = 310.8876)
#     sigma:      45.4227947 +/- 0.45591785 (1.00%) (init = 47)
#     fwhm:       106.962505 +/- 1.07360448 (1.00%) == '2.3548200*sigma'
#     height:     209.759743 +/- 3.47063404 (1.65%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(center, sigma) = -0.134
