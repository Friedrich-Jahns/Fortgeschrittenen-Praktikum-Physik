# %%
__file__ = 'A1.ipynb'
import sys
import pathlib
sys.path.append(str(pathlib.Path(__file__).absolute().parent.parent)+"/FP4_lib")
import functions as f
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from uncertainties import unumpy as up
from uncertainties import ufloat
import scipy.constants as const

# %%
with open('Data/Aufg_5.1.txt','r') as tf:
    data1 = np.genfromtxt(tf).T
with open('Data/Aufg_5.2.txt','r') as tf:
    data2 = np.genfromtxt(tf).T
with open('Data/Aufg_5.3.txt','r') as tf:
    data3 = np.genfromtxt(tf).T
with open('Data/Aufg_5.4.txt','r') as tf:
    data4 = np.genfromtxt(tf).T
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open('Data/Aufg_5.1.txt','r') as tf:
#       2     data1 = np.genfromtxt(tf).T
#       3 with open('Data/Aufg_5.2.txt','r') as tf:
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/Aufg_5.1.txt'

# %%
fig = plt.figure(figsize=(24,9),dpi=80,linewidth=50)
plt.plot(data1[0],data1[1])
plt.show()

fig = plt.figure(figsize=(24,9),dpi=80,linewidth=50)
plt.plot(data2[0],data2[1])
plt.show()

fig = plt.figure(figsize=(24,9),dpi=80,linewidth=50)
plt.plot(data3[0],data3[1])
plt.show()

fig = plt.figure(figsize=(24,9),dpi=80,linewidth=50)
plt.plot(data4[0],data4[1])
plt.show()
